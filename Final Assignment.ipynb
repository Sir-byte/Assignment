# %% [markdown]
# <h1>My Jupiter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b><h2>Paul Oduor Onunga</h2></b> <br>
#     Statistician

# %% [markdown]
# <i>I am interested in data science because this field provides solutions to many problems in the modern life. These solutions cut accross all aspects of life from business to hospitals and even in education sector as data science entails information and models that is relevant to borrow by any field.</i>

# %% [markdown]
# <h3>Performing Addition of Two Numbers</h3>

# %%
2+2
# Out:
# 4

# %% [markdown]
# <hr>Data science is fun because;</hr> <br>
# <ol>
#     <li>Applies programming skills</li>
#     <ul>
#         <li>R</li>
#         <li>SQL</li>
#         <li>Python</li>
#         </ul>
#     <li>Mathematical computation</li>
#     <li>Has a large community</li>
#     <a>Connect to Google</a>
#     </ol>
#
#   <blockquote>The best way to learn data science is to do data science</blockquote>
